# %%
# 引入模組
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as animation # 動態
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.offline import iplot, init_notebook_mode
import pymysql
import chartify
from sqlalchemy import create_engine
import datetime
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# 建立MySQL連線
dbBase = pymysql.connect(host='140.134.51.26', port=3306, user='root', passwd='Gtml@3777', db='ResourceApp', charset='utf8')

# %%
# 框範圍
sql = "SELECT R.ip,R.ReceiveTime,R.hrSWRunName,R.hrSWRunPath,R.hrSWRunPerfCPU, R.hrSWRunPerfMem,H.SoftName, H.SoftGroup1,H.SoftGroup2,C.SoftName as  SoftNameWare, C.SoftClass as SoftClassWare, C.SoftType, C.Unit, C.SoftApp, SP.SoftName as SystemName, concat(hrSWRunPath, hrSWRunName) as Paths \
FROM ResourceApp.HrSWRun AS R \
LEFT join ResourceApp.ConfSoftHistoryList AS H \
ON R.hrSWRunName = H.SoftRun AND concat(R.hrSWRunPath, R.hrSWRunName) = H.SoftPath \
LEFT JOIN ResourceApp.ConfSoftwareList AS C \
ON C.SoftName = H.SoftName \
LEFT JOIN ResourceApp.SystemProcess as SP \
ON R.hrSWRunName = SP.SoftRun \
where R.ReceiveTime >= '2020-07-25' AND R.ReceiveTime < '2020-07-26'"
df = pd.read_sql(sql, dbBase)

# %%
df
# Out:
#                      ip         ReceiveTime      hrSWRunName  \
# 0       140.134.213.101 2020-07-25 00:01:34        lsass.exe
# 1       140.134.213.101 2020-07-25 00:06:39        lsass.exe
# 2       140.134.213.101 2020-07-25 00:11:44        lsass.exe
# 3       140.134.213.101 2020-07-25 00:16:49        lsass.exe
# 4       140.134.213.101 2020-07-25 00:21:54        lsass.exe
# ...                 ...                 ...              ...
# 625934   140.134.211.52 2020-07-25 23:57:41  SelfService.exe
# 625935   140.134.211.52 2020-07-25 23:57:41   bufmonitor.exe
# 625936   140.134.211.52 2020-07-25 23:57:41   redirector.exe
# 625937   140.134.211.52 2020-07-25 23:57:41     TiWorker.exe
# 625938   140.134.211.52 2020-07-25 23:57:41     wfcrun32.exe
#
#                                               hrSWRunPath  hrSWRunPerfCPU  \
# 0                                                    None            7800
# 1                                                    None            7810
# ...

# %%
# df["SystemType"] = 0
# df.query('SystemName.notnull()')
# Out:
#                      ip         ReceiveTime   hrSWRunName  \
# 0       140.134.213.101 2020-07-25 00:01:34     lsass.exe
# 1       140.134.213.101 2020-07-25 00:06:39     lsass.exe
# 2       140.134.213.101 2020-07-25 00:11:44     lsass.exe
# 3       140.134.213.101 2020-07-25 00:16:49     lsass.exe
# 4       140.134.213.101 2020-07-25 00:21:54     lsass.exe
# ...                 ...                 ...           ...
# 624800   140.134.211.15 2020-07-25 23:57:41  WmiPrvSE.exe
# 624801   140.134.211.15 2020-07-25 23:57:41  WmiPrvSE.exe
# 624802   140.134.211.52 2020-07-25 23:57:41  WmiPrvSE.exe
# 624803   140.134.211.52 2020-07-25 23:57:41  WmiPrvSE.exe
# 624804   140.134.211.52 2020-07-25 23:57:41  WmiPrvSE.exe
#
#                       hrSWRunPath SoftName SoftGroup1 SoftNameWare  \
# 0                            None     None       None         None
# 1                            None     None       None         None
# ...

# %%
# dfA = df.query('SystemName.notnull()')
# dfA["SystemType"] = 2

# %%
# dfA
# Out:
#                      ip         ReceiveTime   hrSWRunName  \
# 0       140.134.213.101 2020-07-25 00:01:34     lsass.exe
# 1       140.134.213.101 2020-07-25 00:06:39     lsass.exe
# 2       140.134.213.101 2020-07-25 00:11:44     lsass.exe
# 3       140.134.213.101 2020-07-25 00:16:49     lsass.exe
# 4       140.134.213.101 2020-07-25 00:21:54     lsass.exe
# ...                 ...                 ...           ...
# 624800   140.134.211.15 2020-07-25 23:57:41  WmiPrvSE.exe
# 624801   140.134.211.15 2020-07-25 23:57:41  WmiPrvSE.exe
# 624802   140.134.211.52 2020-07-25 23:57:41  WmiPrvSE.exe
# 624803   140.134.211.52 2020-07-25 23:57:41  WmiPrvSE.exe
# 624804   140.134.211.52 2020-07-25 23:57:41  WmiPrvSE.exe
#
#                       hrSWRunPath SoftName SoftGroup1 SoftNameWare  \
# 0                            None     None       None         None
# 1                            None     None       None         None
# ...

# %%
# dfB = df.query('SoftGroup1.notnull()')
# dfB["SystemType"] = 1

# %%
df["SystemType"] = 0
def bindClass(row):
    if pd.notnull(row["SystemName"]):
        row["ClassType"] = 2
    elif pd.notnull(row["SoftGroup1"]):
        row["ClassType"] = 1
    else:
        row["ClassType"] = 0
    return row

df = df.apply(bindClass, axis=1)

# %%
dfT = df.loc[:,["ip","ReceiveTime","hrSWRunName","Paths","SoftName","SoftGroup1","SoftGroup2","SoftClassWare","SoftType","Unit","SoftApp","hrSWRunPerfCPU","hrSWRunPerfMem"]]
dfT["CreateTime"] = datetime.datetime.now()
dfT
# Out:
#                      ip         ReceiveTime      hrSWRunName  \
# 0       140.134.213.101 2020-07-25 00:01:34        lsass.exe
# 1       140.134.213.101 2020-07-25 00:06:39        lsass.exe
# 2       140.134.213.101 2020-07-25 00:11:44        lsass.exe
# 3       140.134.213.101 2020-07-25 00:16:49        lsass.exe
# 4       140.134.213.101 2020-07-25 00:21:54        lsass.exe
# ...                 ...                 ...              ...
# 625934   140.134.211.52 2020-07-25 23:57:41  SelfService.exe
# 625935   140.134.211.52 2020-07-25 23:57:41   bufmonitor.exe
# 625936   140.134.211.52 2020-07-25 23:57:41   redirector.exe
# 625937   140.134.211.52 2020-07-25 23:57:41     TiWorker.exe
# 625938   140.134.211.52 2020-07-25 23:57:41     wfcrun32.exe
#
#                                                     Paths SoftName SoftGroup1  \
# 0                                                    None     None       None
# ...

# %%
# engine = create_engine("mysql+pymysql://root:Gtml%403777@140.134.51.26:3306/ResourceApp?charset=utf8")
# connection = engine.raw_connection()
# dfT.to_sql('SoftProcessInfo', connection, if_exists="replace", index=False) 
dtype={"age": Integer(), "name": String(30)}
dfT.to_sql(con=dbBase, name="SoftProcessInfo", if_exists="replace", index=False, index_label="RowNum")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1585         try:
# -> 1586             cur.execute(*args, **kwargs)
#    1587             return cur
#
# /usr/local/python3/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     167
# --> 168         query = self.mogrify(query, args)
#     169
#
# /usr/local/python3/lib/python3.7/site-packages/pymysql/cursors.py in mogrify(self, query, args)
#     146         if args is not None:
# --> 147             query = query % self._escape_args(args, conn)
#     148
#
# TypeError: not all arguments converted during string formatting
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# ...

# %%
df.query('ClassType == 2')
# Out:
#                      ip         ReceiveTime   hrSWRunName  \
# 0       140.134.213.101 2020-07-25 00:01:34     lsass.exe
# 1       140.134.213.101 2020-07-25 00:06:39     lsass.exe
# 2       140.134.213.101 2020-07-25 00:11:44     lsass.exe
# 3       140.134.213.101 2020-07-25 00:16:49     lsass.exe
# 4       140.134.213.101 2020-07-25 00:21:54     lsass.exe
# ...                 ...                 ...           ...
# 624800   140.134.211.15 2020-07-25 23:57:41  WmiPrvSE.exe
# 624801   140.134.211.15 2020-07-25 23:57:41  WmiPrvSE.exe
# 624802   140.134.211.52 2020-07-25 23:57:41  WmiPrvSE.exe
# 624803   140.134.211.52 2020-07-25 23:57:41  WmiPrvSE.exe
# 624804   140.134.211.52 2020-07-25 23:57:41  WmiPrvSE.exe
#
#                       hrSWRunPath SoftName SoftGroup1 SoftNameWare  \
# 0                            None     None       None         None
# 1                            None     None       None         None
# ...

# %%
sql = "SELECT SoftName, SoftRun, Category FROM ResourceApp.SystemProcess"
df = pd.read_sql(sql, dbBase)
