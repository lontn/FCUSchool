# %%
# 引入模組
import numpy as np
import pandas as pd
import datetime
import pymysql

# %%
# 建立MySQL連線
dbBase = pymysql.connect(host='140.134.51.26', port=3306, user='root', passwd='Gtml@3777', db='ResourceApp', charset='utf8')

# %%
# 框範圍
sql = "SELECT * FROM ResourceApp.UV_SoftProcessInfo \
WHERE ReceiveTime >= '2020-07-25' AND ReceiveTime < '2020-07-26' \
Order By ip ASC, ReceiveTime DESC"
df = pd.read_sql(sql, dbBase)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 625939 entries, 0 to 625938
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Id              625939 non-null  int64
#  1   ip              625939 non-null  object
#  2   ReceiveTime     625939 non-null  datetime64[ns]
#  3   hrSWRunName     625939 non-null  object
#  4   ProcessPath     249647 non-null  object
#  5   SoftName        1556 non-null    object
#  6   SoftGroup1      1556 non-null    object
#  7   SoftGroup2      1556 non-null    object
#  8   SoftClass       0 non-null       object
#  9   SoftType        0 non-null       object
#  10  Unit            0 non-null       object
#  11  SoftApp         0 non-null       object
#  12  hrSWRunPerfCPU  625939 non-null  int64
#  13  hrSWRunPerfMem  625939 non-null  int64
#  14  SystemType      625939 non-null  int64
#  15  CreateTime      625939 non-null  datetime64[ns]
# ...

# %%
df.head(10)
# Out:
#        Id              ip         ReceiveTime  hrSWRunName  \
# 0  548096  140.134.211.10 2020-07-25 16:54:48  svchost.exe
# 1  548097  140.134.211.10 2020-07-25 16:54:48  svchost.exe
# 2  548098  140.134.211.10 2020-07-25 16:54:48  svchost.exe
# 3  548099  140.134.211.10 2020-07-25 16:54:48  svchost.exe
# 4  548100  140.134.211.10 2020-07-25 16:54:48  svchost.exe
# 5  548101  140.134.211.10 2020-07-25 16:54:48  svchost.exe
# 6  548102  140.134.211.10 2020-07-25 16:54:48  svchost.exe
# 7  548103  140.134.211.10 2020-07-25 16:54:48  svchost.exe
# 8  548104  140.134.211.10 2020-07-25 16:54:48  svchost.exe
# 9  548105  140.134.211.10 2020-07-25 16:54:48  svchost.exe
#
#                        ProcessPath SoftName SoftGroup1 SoftGroup2 SoftClass  \
# 0  C:\Windows\system32\svchost.exe     None       None       None      None
# 1  C:\Windows\system32\svchost.exe     None       None       None      None
# 2  C:\Windows\System32\svchost.exe     None       None       None      None
# ...

# %%
df.tail(10)
# Out:
#           Id               ip         ReceiveTime              hrSWRunName  \
# 625929  2038  140.134.213.101 2020-07-25 00:01:34                Skype.exe
# 625930  2039  140.134.213.101 2020-07-25 00:01:34    SelfServicePlugin.exe
# 625931  2040  140.134.213.101 2020-07-25 00:01:34  ConfigurationWizard.exe
# 625932  2041  140.134.213.101 2020-07-25 00:01:34  ShellExperienceHost.exe
# 625933  2042  140.134.213.101 2020-07-25 00:01:34            WeChatWeb.exe
# 625934  2043  140.134.213.101 2020-07-25 00:01:34               chrome.exe
# 625935  2044  140.134.213.101 2020-07-25 00:01:34                Teams.exe
# 625936  2045  140.134.213.101 2020-07-25 00:01:34        RuntimeBroker.exe
# 625937  2046  140.134.213.101 2020-07-25 00:01:34               chrome.exe
# 625938  2047  140.134.213.101 2020-07-25 00:01:34             Video.UI.exe
#
#        ProcessPath SoftName SoftGroup1 SoftGroup2 SoftClass SoftType  Unit  \
# ...

# %%
df_s1 = df[df["SystemType"] == 1]

# %%
df_s1
# Out:
#             Id              ip         ReceiveTime hrSWRunName  \
# 390     542415  140.134.211.10 2020-07-25 16:45:14   Revit.exe
# 394     542418  140.134.211.10 2020-07-25 16:45:14   Revit.exe
# 1233    485459  140.134.211.10 2020-07-25 15:57:11   Revit.exe
# 1237    485462  140.134.211.10 2020-07-25 15:57:11   Revit.exe
# 2733    399794  140.134.211.10 2020-07-25 14:50:20   Revit.exe
# ...        ...             ...                 ...         ...
# 560758  113611   140.134.211.9 2020-07-25 10:45:32   Revit.exe
# 560937  104641   140.134.211.9 2020-07-25 10:36:19   Revit.exe
# 560945  104648   140.134.211.9 2020-07-25 10:36:19   Revit.exe
# 561088   87963   140.134.211.9 2020-07-25 10:27:09   Revit.exe
# 561092   87966   140.134.211.9 2020-07-25 10:27:09   Revit.exe
#
#                                            ProcessPath             SoftName  \
# 390     C:\Program Files\Autodesk\Revit 2019\Revit.exe  Autodesk Revit 2019
# ...

# %%
df_s1 = df.query("SystemType == 1")

# %%
df_s1
# Out:
#             Id              ip         ReceiveTime hrSWRunName  \
# 390     542415  140.134.211.10 2020-07-25 16:45:14   Revit.exe
# 394     542418  140.134.211.10 2020-07-25 16:45:14   Revit.exe
# 1233    485459  140.134.211.10 2020-07-25 15:57:11   Revit.exe
# 1237    485462  140.134.211.10 2020-07-25 15:57:11   Revit.exe
# 2733    399794  140.134.211.10 2020-07-25 14:50:20   Revit.exe
# ...        ...             ...                 ...         ...
# 560758  113611   140.134.211.9 2020-07-25 10:45:32   Revit.exe
# 560937  104641   140.134.211.9 2020-07-25 10:36:19   Revit.exe
# 560945  104648   140.134.211.9 2020-07-25 10:36:19   Revit.exe
# 561088   87963   140.134.211.9 2020-07-25 10:27:09   Revit.exe
# 561092   87966   140.134.211.9 2020-07-25 10:27:09   Revit.exe
#
#                                            ProcessPath             SoftName  \
# 390     C:\Program Files\Autodesk\Revit 2019\Revit.exe  Autodesk Revit 2019
# ...

# %%
df_s0 = df.query("SystemType == 0")
df_s0
# Out:
#             Id               ip         ReceiveTime        hrSWRunName  \
# 76      550726   140.134.211.10 2020-07-25 16:54:48      Secure System
# 77      550727   140.134.211.10 2020-07-25 16:54:48         LsaIso.exe
# 78      550728   140.134.211.10 2020-07-25 16:54:48       WUDFHost.exe
# 79      550729   140.134.211.10 2020-07-25 16:54:48    fontdrvhost.exe
# 80      550730   140.134.211.10 2020-07-25 16:54:48    fontdrvhost.exe
# ...        ...              ...                 ...                ...
# 625934    2043  140.134.213.101 2020-07-25 00:01:34         chrome.exe
# 625935    2044  140.134.213.101 2020-07-25 00:01:34          Teams.exe
# 625936    2045  140.134.213.101 2020-07-25 00:01:34  RuntimeBroker.exe
# 625937    2046  140.134.213.101 2020-07-25 00:01:34         chrome.exe
# 625938    2047  140.134.213.101 2020-07-25 00:01:34       Video.UI.exe
#
#                                ProcessPath SoftName SoftGroup1 SoftGroup2  \
# ...

# %%
df_s0_1 = df.query("SystemType == 0 or SystemType == 1")
df_s0_1
# Out:
#             Id               ip         ReceiveTime        hrSWRunName  \
# 76      550726   140.134.211.10 2020-07-25 16:54:48      Secure System
# 77      550727   140.134.211.10 2020-07-25 16:54:48         LsaIso.exe
# 78      550728   140.134.211.10 2020-07-25 16:54:48       WUDFHost.exe
# 79      550729   140.134.211.10 2020-07-25 16:54:48    fontdrvhost.exe
# 80      550730   140.134.211.10 2020-07-25 16:54:48    fontdrvhost.exe
# ...        ...              ...                 ...                ...
# 625934    2043  140.134.213.101 2020-07-25 00:01:34         chrome.exe
# 625935    2044  140.134.213.101 2020-07-25 00:01:34          Teams.exe
# 625936    2045  140.134.213.101 2020-07-25 00:01:34  RuntimeBroker.exe
# 625937    2046  140.134.213.101 2020-07-25 00:01:34         chrome.exe
# 625938    2047  140.134.213.101 2020-07-25 00:01:34       Video.UI.exe
#
#                                ProcessPath SoftName SoftGroup1 SoftGroup2  \
# ...

# %%
df
# Out:
#             Id               ip         ReceiveTime        hrSWRunName  \
# 0       548096   140.134.211.10 2020-07-25 16:54:48        svchost.exe
# 1       548097   140.134.211.10 2020-07-25 16:54:48        svchost.exe
# 2       548098   140.134.211.10 2020-07-25 16:54:48        svchost.exe
# 3       548099   140.134.211.10 2020-07-25 16:54:48        svchost.exe
# 4       548100   140.134.211.10 2020-07-25 16:54:48        svchost.exe
# ...        ...              ...                 ...                ...
# 625934    2043  140.134.213.101 2020-07-25 00:01:34         chrome.exe
# 625935    2044  140.134.213.101 2020-07-25 00:01:34          Teams.exe
# 625936    2045  140.134.213.101 2020-07-25 00:01:34  RuntimeBroker.exe
# 625937    2046  140.134.213.101 2020-07-25 00:01:34         chrome.exe
# 625938    2047  140.134.213.101 2020-07-25 00:01:34       Video.UI.exe
#
#                             ProcessPath SoftName SoftGroup1 SoftGroup2  \
# ...
